# %% [markdown]
# $3x_1^2 + 2x_2^2 -14 = 0$
#
# $4x_1x_2 - x_2 + 9 = 0$
#
# Solve the given system with the $x^0 = \left[\begin{array}
# {rrr}
# -1 \\ 0
# \end{array}\right]$ and be sure error tolerance is less than 10^{(-2)}.
#
# Solution:
#
# $f(x^{(0)}) = \left[\begin{array}
# {rrr}
# 3.1 + 2.0 - 14 \\ 4.1.0 - 0 + 9
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -11 \\ 9
# \end{array}\right] \to |f(x^{(0)})| > \epsilon$
#
# $J = \left[\begin{array}
# {rrr}
# 6x_1 & 4x_2 \\ 4x_1 & 4x_1 - 1
# \end{array}\right]$
#
# $J(x^{(0)}) = J\left[\begin{array}
# {rrr}
# -1 \\ 0
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -6 & 0 \\ 0 & -5
# \end{array}\right] \to J^{-1}(x^{(0)}) = \left[\begin{array}
# -1/6 & 0 \\ 0 & -1/5
# \end{array}\right] = \left[\begin{array}
# -0,167 & 0  \\ 0 & -0,2
# \end{array}\right]$
#
# **(*)**  $x^{(k+1)} = x^{(k)} - J^{-1}(x^{(t)}f(x^{(t)}))$
#
# $x^{(1)} = x^{(0)} - J^{(-1)}(x^{(0)})f(x^{(0)}) \to x^{(1)} = \left[\begin{array}
# {rrr}
# -1 \\ 0
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,167 & 0  \\ 0 & -0,2
# \end{array}\right]\left[\begin{array}
# {rrr}
# -11  \\ 9
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -1  \\ 0
# \end{array}\right] - \left[\begin{array}
# {rrr}
#  1,837 \\ -1,8
# \end{array}\right]$
#
# $x^{(1)} = \left[\begin{array}
# {rrr}
# -2,857 \\ 1,8
# \end{array}\right]$
#
# $f(x^{(1)}) = \left[\begin{array}
# {rrr}
# 3(-2,837)^2 + 2(1,87)^2 - 14 \\ 4(-2,837)(1,8) - (1,8) + 9
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 16,63 \\ -13,23
# \end{array}\right] \to ||f(x^{(1)})|| > \epsilon$
#
# $J(x^{(1)}) = J\left[\begin{array}
# {rrr}
# -2,857 \\ 1,8
# \end{array}\right]) = \left[\begin{array}
# {rrr}
# 6(-2,837) & 4(1,8) \\ 4(1,8) & 4(-2,837) -1
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -17,02 & 7,2 \\ 7,2 & -12,35
# \end{array}\right]$
#
# $J^{-1}(x^{(1)}) = \left[\begin{array}
# {rrr}
# -0,077 & -0,045 \\ -0,045 & 0,107
# \end{array}\right]$
#
# **(*)** numbered equation:
#
# $x^{(2)} = x^{(1)} - J^{-1}(x^{(1)})f(x^{(1)})$
#
# $x^{(1)} = \left[\begin{array}
# {rrr}
# -2,837 \\ 1,8
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,077 & -0,045 \\ -0,045 & 0,107
# \end{array}\right]\left[\begin{array}
# {rrr}
# 16,63 \\ -13,23,
# \end{array}\right]$
#
# $x^{(2)} = \left[\begin{array}
# {rrr}
# -2,837 \\ 1,8
# \end{array}\right] - \left[\begin{array}
# {rrr}
# 0,685 \\ 0,66
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -2,152 \\ 1,14
# \end{array}\right]$
#
# $f(x^{(2)}) = \left[\begin{array}
# {rrr}
# 3(-2,152)^2 + 2(1,14)^2 - 14\\ 4(2,152)(1,14) - (1,14) + 9
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 2,49 \\ -1,95
# \end{array}\right] \to ||f(x^{(2)})|| > \epsilon$
#
# $J(x^{(2)}) = J\left[\begin{array}
# {rrr}
# 2,152 \\ 1,14
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 6(-2,152) & 4(1,14) \\ 4(1,14) & 4(-2,152) - 1
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 12,91 & 4,56\\4,45 & -9,6
# \end{array}\right]$
#
# $J^{-1}(x^{(2)}) = \left[\begin{array}
# {rrr}
# -0,09 & -0,044\\-0,044 & -0,125
# \end{array}\right]$
#
# from **(*)** numbered equation $x^{(3)} = x^{(2)} - J^{-1}(x^{(2)})f(x^{(2)})$
#
# $x^{(3)} = \left[\begin{array}
# {rrr}
# 2,152 \\ 1,14
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,09 & -0,044\\-0,044 & -0,125
# \end{array}\right] \left[\begin{array}
# {rrr}
# 2,49\\-1,95
# \end{array}\right]$
#
# $x^{(3)} = \left[\begin{array}
# {rrr}
# 2,152 \\ 1,14
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,13 \\ 0,13
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -2,02 \\ 1,01
# \end{array}\right]$
#
# $f(x^{(3)}) = \left[\begin{array}
# {rrr}
# 3(-2,02)^2 + 2(1,01)^2 - 14\\ 4(-2,02)(1,01) - (1,01) + 9
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 0,88 \\ -0,17
# \end{array}\right] \to ||f(x^{(3)}|| > \epsilon$
#
# $J(x^{3}) = J\left[\begin{array}
# {rrr}
# -2,02 \\ 1,01
# \end{array}\right] = \left[\begin{array}
# {rrr}
# 6(-2,02) & 4(1,01) \\ 4(1,01) & 4(-2,02) - 1
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -12,12 & 4,04\\ 2,04 & -9,08
# \end{array}\right]$
#
# $J^{-1}(x^{(3)}) = \left[\begin{array}
# {rrr}
# -0,09 & -0,043\\ -0,043 & -0,129
# \end{array}\right]$
#
# from **(*)** equation $x^{(4)} = x^{(3)} - J^{-1}(x^{(3)})f(x^{(3)})$
#
# $x^{(4)} = \left[\begin{array}
# {rrr}
# -2,02 \\ 1,01
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,09 & -0,043\\ -0,043 & -0,129
# \end{array}\right]\left[\begin{array}
# {rrr}
# 0,28\\-0,17
# \end{array}\right]$
#
# $x^{(4)} = \left[\begin{array}
# {rrr}
# -2,02 \\ 1,01
# \end{array}\right] - \left[\begin{array}
# {rrr}
# -0,17 \\ 0,009
# \end{array}\right] = \left[\begin{array}
# {rrr}
# -1,85 \\ 1,001
# \end{array}\right]$
#
# $f(x^{(4)}) = \left[\begin{array}
# {rrr}
# 3(-1,85)^2 + 2(1,001)^2 - 14 \\ 4(-1,85)(1,001) - (1,001) + 9
# \end{array}\right]$
#
# $f(x^{(4)}) = \left[\begin{array}
# {rrr}
# -1,73 \\ 0,59
# \end{array}\right]$
#
# $||f(x^{(4)})|| = 0,0067 < \epsilon = 0,01$

# %%
# Halil Serdar 090180329
# Tarık Kayalı 090180358
# Emir Berke Özkan 090180341
